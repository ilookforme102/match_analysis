# %%
import openai
import time
import numpy as np
import json
import math
import requests
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import openai
#       2 import time
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'openai'

# %%
wpdbtt_api_match_h2h

sql_dabanhtructi

FKb75AYJzFMJET8F

128.199.228.235

port: 3306

wpdbtt_api_analysis

# %%
# Establish a database connection
conn = pymysql.connect(
    host='128.199.228.235', 
    user='sql_dabanhtructi', 
    password='FKb75AYJzFMJET8F', 
    database='sql_dabanhtructi',
    port = 3306
)

# Create a cursor object
cursor = conn.cursor()

# Execute a query
cursor.execute("""SELECT m.id, c.name as competition, v.name as stadium , v.city city, home_team.name home_team, away_team.name away_team, m.match_time match_time, h.h2h, h.home ,h.away, m.home_scores home_scores, m.away_scores away_scores 
FROM `wpdbtt_api_matches` as m 
LEFT JOIN `wpdbtt_api_competition` as c 
ON m.competition_id = c.competition_id 
LEFT JOIN `wpdbtt_api_venue` as v 
ON m.venue_id = v.venue_id 
LEFT JOIN `wpdbtt_api_team` as home_team 
ON m.home_team_id = home_team.team_id 
LEFT JOIN `wpdbtt_api_team` as away_team 
ON m.away_team_id = away_team.team_id 
LEFT JOIN `wpdbtt_api_match_h2h` as h 
ON m.id = h.match_id 
WHERE m.match_time >= 1702828800 AND m.match_time <1702915200 AND home_team.name = 'Backa Topola'
ORDER BY `m`.`match_time` DESC LIMIT 5
""")

# Fetch all the rows in a list of lists.
rows = cursor.fetchall()
for row in rows:
    print(row)

# Close the cursor and connection
cursor.close()
conn.close()
# Out:
# ('k82rekh0l7xdrep', 'Serbian Super liga', 'Stadion Senta', 'Senta', 'Backa Topola', 'Habitpharm Javor', 1702911600, '[{"competition_id":"yl5ergphk2r8k0o","competition_name":"Serbian Super liga","competition_logo":"\\/football\\/competition\\/53c39d0e222d0707324dcf86dd20ca23.png","matches":[{"match_id":"k82rekh0l73wrep","match_time":1692552600,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,0,3,6,0,0],"away_scores":[3,3,0,2,5,0,0]},{"match_id":"y0or5jhz04dyqwz","match_time":1667044800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,0,2,6,0,0],"away_scores":[1,0,0,2,5,0,0]},{"match_id":"318q66h670xzqo9","match_time":1657994400,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[0,0,0,0,5,0,0],"away_scores":[0,0,0,4,0,0,0]},{"match_id":"4wyrn4hllxvpq86","match_time":1620563400,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[2,2,1,2,3,0,0],"away_scores":[1,1,0,3,3,0,0]},{"match_id":"4jwq2gh917kom0v","match_time":1608472800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[1,0,1,3,6,0,0],"away_scores":[2,0,0,2,4,0,0]},{"match_id":"8yomo4h9k869q0j","match_time":1590939000,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[6,2,0,1,7,0,0],"away_scores":[1,0,0,1,10,0,0]},{"match_id":"6ypq3nhg587wmd7","match_time":1571500800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[3,1,0,5,5,0,0],"away_scores":[2,2,0,3,6,0,0]}]},{"competition_id":"kjw2r09h59rz84o","competition_name":"Serbian Prva Liga","competition_logo":"\\/football\\/competition\\/14c0fe418966f38de7fb573148830ed6.png","matches":[{"match_id":"pxwrxlh2ddgyryk","match_time":1554559200,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[4,2,0,0,-1,0,0],"away_scores":[2,1,0,0,-1,0,0]},{"match_id":"jw2r09hpky1drz8","match_time":1543406400,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[3,3,0 ...

# %% [markdown]
# SELECT m.id, c.name as competition, v.name as stadium , v.city city, home_team.name home_team, away_team.name away_team, m.match_time match_time, h.h2h, h.home ,h.away, m.home_scores home_scores, m.away_scores away_scores
# FROM `wpdbtt_api_matches` as m
# LEFT JOIN `wpdbtt_api_competition` as c
# ON m.competition_id = c.competition_id
# LEFT JOIN `wpdbtt_api_venue` as v
# ON m.venue_id = v.venue_id
# LEFT JOIN `wpdbtt_api_team` as home_team
# ON m.home_team_id = home_team.team_id
# LEFT JOIN `wpdbtt_api_team` as away_team
# ON m.away_team_id = away_team.team_id
# LEFT JOIN `wpdbtt_api_match_h2h` as h
# ON m.id = h.match_id
# WHERE m.match_time >= 1702828800 AND m.match_time <1702915200
# ORDER BY `m`.`match_time` DESC
# LIMIT 100

# %%
match_dict = {}
for index,row in enumerate(rows):
    item = {'match_id':row[0],
            'competition': row[1],
            'stadium':row[2],
            'city':row[3],
            'home_team':row[4],
            'away_team':row[5],
            'match_time':row[6],
            'h2h':row[7],
            'home':row[8],
            'away':row[9]
           }
    match_dict[index] = item

# %%
test = match_dict[0]

# %%
match_dict
# Out:
# {0: {'match_id': 'k82rekh0l7xdrep',
#   'competition': 'Serbian Super liga',
#   'stadium': 'Stadion Senta',
#   'city': 'Senta',
#   'home_team': 'Backa Topola',
#   'away_team': 'Habitpharm Javor',
#   'match_time': 1702911600,
#   'h2h': '[{"competition_id":"yl5ergphk2r8k0o","competition_name":"Serbian Super liga","competition_logo":"\\/football\\/competition\\/53c39d0e222d0707324dcf86dd20ca23.png","matches":[{"match_id":"k82rekh0l73wrep","match_time":1692552600,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,0,3,6,0,0],"away_scores":[3,3,0,2,5,0,0]},{"match_id":"y0or5jhz04dyqwz","match_time":1667044800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,0,2,6,0,0],"away_scores":[1,0,0,2,5,0,0]},{"match_id":"318q66h670xzqo9","match_time":1657994400,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[0,0,0,0,5,0,0],"away_scores":[0,0,0,4,0,0,0]},{"match_id":"4wyrn4hllxvpq86","match_time":1620563400,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[2,2,1,2,3,0,0],"away_scores":[1,1,0,3,3,0,0]},{"match_id":"4jwq2gh917kom0v","match_time":1608472800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[1,0,1,3,6,0,0],"away_scores":[2,0,0,2,4,0,0]},{"match_id":"8yomo4h9k869q0j","match_time":1590939000,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[6,2,0,1,7,0,0],"away_scores":[1,0,0,1,10,0,0]},{"match_id":"6ypq3nhg587wmd7","match_time":1571500800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[3,1,0,5,5,0,0],"away_scores":[2,2,0,3,6,0,0]}]},{"competition_id":"kjw2r09h59rz84o","competition_name":"Serbian Prva Liga","competition_logo":"\\/football\\/competition\\/14c0fe418966f38de7fb573148830ed6.png","matches":[{"match_id":"pxwrxlh2ddgyryk","match_time":1554559200,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[4,2,0,0,-1,0,0],"away_scores":[2,1,0,0,-1,0,0]},{"match_id":"jw2r09hpky1drz8","match_time":1543406400,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[3,3,0,2,4,0,0],"away_scores":[1,1,0,3,3,0,0]},{"match_id":"n54qllhkng2vqvy","match_time":1535216400,"status_id": ...
#   'home': '[{"competition_id":"56ypq3nh0xmd7oj","competition_name":"UEFA Europa League","competition_logo":"\\/football\\/competition\\/1792ba5a12171fedc6d543bdf173f37c.png","matches":[{"match_id":"dn1m1gh24z2kmoe","match_time":1702584000,"status_id":8,"home_team_id":"56ypq3nhywpmd7o","home_name":"Olympiakos Piraeus","home_logo":"\\/football\\/team\\/fcf62204578f5bbf95d254759781bef7.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[5,3,0,0,3,0,0],"away_scores":[2,0,1,5,1,0,0]},{"match_id":"2y8m4zh6396vql0","match_time":1701366300,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"gy0or5jhdwxqwzv","away_name":"West Ham United","away_logo":"\\/football\\/team\\/d71ebda5c7fbca9093a1c2978c46f619.png","home_scores":[0,0,0,2,1,0,0],"away_scores":[1,0,0,2,8,0,0]},{"match_id":"dj2ryoh1k01lq1z","match_time":1699560000,"status_id":8,"home_team_id":"l965mkyh924r1ge","home_name":"SC Freiburg","home_logo":"\\/football\\/team\\/6508946c9a5fe22a8784b905b25e8c79.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[5,1,0,1,10,0,0],"away_scores":[0,0,0,1,3,0,0]},{"match_id":"6ypq3nh30o3pmd7","match_time":1698338700,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"l965mkyh924r1ge","away_name":"SC Freiburg","away_logo":"\\/football\\/team\\/6508946c9a5fe22a8784b905b25e8c79.png","home_scores":[1,1,0,3,1,0,0],"away_scores":[3,0,0,1,5,0,0]},{"match_id":"8yomo4h37o38q0j","match_time":1696524300,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"56ypq3nhywpmd7o","away_name":"Olympiakos Piraeus","away_logo":"\\/football\\/team\\/fcf62204578f5bbf95d254759781bef7.png","home_scores":[2,0,0,1,1,0,0],"away_scores":[2,1,1,1,3,0,0]},{"match_id":"318q66hwopw7qo9","match_time":1695322800,"status_id":8,"home_team_id":"gy0or5jhdwxqwzv","home_name":"West Ham United","home_logo":"\\/football\\/team\\/d71ebda5c7fbca9093a1c2978c46f619.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[3,0,0,1,12,0,0],"away_scores":[1,0,0,1,4,0,0]}]},{"competition_id":"yl5ergphk2r8k0o","competition_name":"Serbian Super liga","competition_logo":"\\/football\\/competition\\/53c39d0e222d0707324dcf86dd20ca23.png","matches":[{"match_id":"3glrw7h3dvpzqdy","match_time":1702123200,"status_id":8,"home_team_id":"k82rekhvekkrepz","home_name":"Radnicki 1923 Kragujevac","home_logo":"\\/football\\/team\\/33e7ad6e34950bb9743e157561f60341.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,1,2,0,0,0],"away_scores":[0,0,0,2,3,0,0]},{"match_id":"2y8m4zhwlkp3ql0","match_time":1701619200,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"d23xmvkh5k4qg8n","away_name":"Radnicki Nis","away_logo":"\\/football\\/team\\/794c52e40471e247cc8e50dc33841c1d.png","home_scores":[1,0,0,3,7,0,0],"away_scores":[0,0,1,2,1,0,0]},{"match_id":"1l4rjnhjvw54m7v","match_time":1700933400,"status_id":8,"home_team_id":"gpxwrxlhogxryk0","home_name":"Partizan Belgrade","home_logo":"\\/football\\/team\\/f2cc8904afb100d60dfe9266b3ded7cf.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,0,3,3,0,0],"away_scores":[4,3,0,2,5,0,0]},{"match_id":"y0or5jhz726jqwz","match_time":1699813800,"status_id":8, ...
#   'away': '[{"competition_id":"yl5ergphk2r8k0o","competition_name":"Serbian Super liga","competition_logo":"\\/football\\/competition\\/53c39d0e222d0707324dcf86dd20ca23.png","matches":[{"match_id":"pxwrxlhxdk3jryk","match_time":1702216800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"56ypq3nh2p9md7o","away_name":"FK \\u010cukari\\u010dki","away_logo":"\\/football\\/team\\/4ad5f5bcfdad804518271ed830bbecc1.png","home_scores":[1,0,0,5,1,0,0],"away_scores":[2,1,0,1,6,0,0]},{"match_id":"jw2r09h68o9erz8","match_time":1701444600,"status_id":8,"home_team_id":"kn54qllhg5yqvy9","home_name":"Novi Pazar","home_logo":"\\/football\\/team\\/993a9b2e250b69aabc350618ada0b139.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[2,0,0,2,2,0,0],"away_scores":[0,0,1,5,3,0,0]},{"match_id":"zp5rzgh68l46q82","match_time":1701097200,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"4zp5rzghlweq82w","away_name":"FK Vozdovac Beograd","away_logo":"\\/football\\/team\\/cd95dbc4c415200eafa8f40625fe59a7.png","home_scores":[4,1,0,2,3,0,0],"away_scores":[0,0,0,0,6,0,0]},{"match_id":"y0or5jhz726eqwz","match_time":1699803000,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"8yomo4h7zxnq0j6","away_name":"FK Spartak Zlatibor Voda","away_logo":"\\/football\\/team\\/f9febad819c8bf2e552267e14127c5b7.png","home_scores":[2,1,0,2,6,0,0],"away_scores":[0,0,0,1,5,0,0]},{"match_id":"8yomo4hgnd9dq0j","match_time":1699293600,"status_id":8,"home_team_id":"1l4rjnh67zgm7vx","home_name":"Mladost Lucani","home_logo":"\\/football\\/team\\/e64d3418718f4415783fcfaca7db3448.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[1,1,0,4,6,0,0],"away_scores":[0,0,0,2,5,0,0]},{"match_id":"k82rekh0l7nwrep","match_time":1698422400,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"jw2r09hl16yrz84","away_name":"FK Napredak Krusevac","away_logo":"\\/football\\/team\\/7d35c67da2b80a3092e25e784ce21762.png","home_scores":[0,0,1,0,4,0,0],"away_scores":[2,2,0,0,4,0,0]},{"match_id":"x7lm7ph341nom2w","match_time":1697905800,"status_id":8,"home_team_id":"9k82rekh44krepz","home_name":"Crvena Zvezda","home_logo":"\\/football\\/team\\/61a1f9406cde098a265280a3683da9b7.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[3,1,0,0,9,0,0],"away_scores":[2,0,0,3,6,0,0]},{"match_id":"2y8m4zhwlk4oql0","match_time":1696694400,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"FK Zeleznicar Pancevo","home_logo":"\\/football\\/team\\/5a4205b9ee3d49c60df7bf22bc2e2203.png","away_team_id":"23xmvkhdvz8qg8n","away_name":"FK Zeleznicar Pancevo","away_logo":"\\/football\\/team\\/5a4205b9ee3d49c60df7bf22bc2e2203.png","home_scores":[2,1,0,1,5,0,0],"away_scores":[1,0,0,3,7,0,0]},{"match_id":"dn1m1ghp6wo9moe","match_time":1696168800,"status_id":8,"home_team_id":"y39mp1h3ek1mojx","home_name":"Radnik Surdulica","home_logo":"\\/football\\/team\\/cf83cf4ba24bbed391992ef0423a41db.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[0,0,0,1,1,0,0],"away_scores":[1,0,0,1,5,0,0]},{"match_id":"3glrw7h3dvlkqdy","match_time":1695489000,"status_id":8,"home_team_id":"4zp5rzghkp1q82w","home_name":"Vojvodina Novi Sad","home_logo":"\\/football\\/team\\/40ce8b99981bc319 ...

# %%
team1 =  test['home_team']
team2 = test['away_team']
league_name = test['competition']
unix_time = test['match_time']
list_days = {'Mon':'Thứ Hai','Tue':'Thứ Ba','Wed':'Thứ Tư','Thu':'Thứ Năm','Fri':'Thứ Sáu','Sat':'Thứ Bảy','Sun':'Chủ Nhật'}
day_of_week_vi = list_days[time.strftime("%a", time.localtime(unix_time-0*3600))]
date_dmy =time.strftime("%d/%m/%Y", time.localtime(unix_time-0*3600))
time_hm= time.strftime("%H:%M", time.localtime(unix_time-0*3600))

# %%
homeaway_h2h = json.loads(test['h2h'])[0]['matches']

# %%
##home and away head2head stats
#team1 as home 
team1_h2h_home_scores = []
for i in homeaway_h2h:
    if i['home_name']== team1:
        team1_h2h_home_scores.append(i['home_scores'][0])

# %%
#team2 as away
team2_h2h_away_scores = []
for i in homeaway_h2h:
    if i['away_name']== team2:
        team2_h2h_away_scores.append(i['away_scores'][0])

# %%
#Avg team 1 h2h home scores 5 recent games
team1_avg_h2h_home_scores = np.mean(team1_h2h_home_scores[0:5])
#Avg team 2 h2h away score 5 recent games
team2_avg_h2h_away_scores = np.mean(team2_h2h_away_scores[0:5])

# %%
team2_avg_h2h_away_scores
# Out:
# 0.6666666666666666

# %%
#homeaway_h2h

# %%
#H2H recents 5 games
homeaway_h2h = json.loads(test['h2h'])[0]['matches'][0:5]
team1_h2h_stats = {'win':0,'draw':0,'loss':0}
for i in homeaway_h2h:
    if i['home_scores'] > i['away_scores']:
        if i['home_name'] == team1:
            team1_h2h_stats['win']+=1
        else:
            team1_h2h_stats['loss']+=1
    elif i['home_scores'] == i['away_scores']:
        team1_h2h_stats['draw']+=1
    else:
        if i['home_name'] == team1:
            team1_h2h_stats['loss']+=1
        else:
            team1_h2h_stats['win']+=1
#Team1 stats 5 recent games:
home_stats = {'win':0,'draw':0,'loss':0}
homeaway_home  =  json.loads(test['home'])[0]['matches'][0:5]
for i in homeaway_home:
    if i['home_scores'] > i['away_scores']:
        if i['home_name'] == team1:
            home_stats['win']+=1
        else:
            home_stats['loss']+=1
    elif i['home_scores'] == i['away_scores']:
        home_stats['draw']+=1
    else:
        if i['home_name'] == team1:
            home_stats['loss']+=1
        else:
            home_stats['win']+=1
#Team2 stats 5 recent games
away_stats = {'win':0,'draw':0,'loss':0}
homeaway_away =  json.loads(test['away'])[0]['matches'][0:5]
for i in homeaway_away:
    if i['home_scores'] > i['away_scores']:
        if i['home_name'] == team2:
            away_stats['win']+=1
        else:
            away_stats['loss']+=1
    elif i['home_scores'] == i['away_scores']:
        away_stats['draw']+=1
    else:
        if i['home_name'] == team2:
            away_stats['loss']+=1
        else:
            away_stats['win']+=1

# %%
#Team1 GA and GF scores
#team1_home_ga_scores=[]
team1_home_gf_scores=[]
homeaway_home = json.loads(test['home'])[0]['matches']
for i in homeaway_home:
    if i['home_name']== team1:
        team1_home_ga_scores.append(i['home_scores'][0])
        team1_home_gf_scores.append(i['away_scores'][0])
team1_avg_home_gf_scores = np.mean(team1_home_gf_scores)

# %%
team2_away_gf_scores=[]
homeaway_away = json.loads(test['away'])[0]['matches']
for i in homeaway_away:
    if i['away_name']== team2:
        team2_away_gf_scores.append(i['away_scores'][0])
        #team2_away_gf_scores.append(i['home_scores'][0])
team2_avg_away_gf_scores = np.mean(team2_away_gf_scores)

# %%
#team1_home_eg_adjst_ratio = (team1_avg_h2h_home_scores + team1_avg_home_gf_scores)/2
#team2_away_eg_adjst_ratio = (team2_avg_h2h_away_scores + team2_avg_away_gf_scores)/2
#Home and Away EG
home_eg = (team1_avg_h2h_home_scores + team1_avg_home_gf_scores)/2
away_eg = (team2_avg_h2h_away_scores + team2_avg_away_gf_scores)/2
def poisson_goal(g,eg):
    return (math.e**(-eg)*eg**g)/(math.factorial(g))
#Home team goals probabilty, assume goals only in range 0-7
home_goals_probs = []
for i in range(0,8):
    prob = poisson_goal(i,home_eg)
    home_goals_probs.append(prob)
#Away team goals probability, assume that goals are only in range 0-7
away_goals_probs = []
for i in range(0,8):
    prob = poisson_goal(i,away_eg)
    away_goals_probs.append(prob)
#Home and Away goals prediction:
home_goal_pred = home_goals_probs.index(max(home_goals_probs))
away_goal_pred = away_goals_probs.index(max(away_goals_probs))
#Probability that Home team win:
home_win_prob_list = []
for i in range(0,len(home_goals_probs)):
    for j in range(0,len(away_goals_probs)):
        if j < i:
            home_win_prob_list.append(home_goals_probs[i]*away_goals_probs[j])
home_win_prob = sum(home_win_prob_list)
#Probability that both team draw:
draw_prob = sum(np.array(home_goals_probs)*np.array(away_goals_probs))
#Probability that Away team win:
away_win_prob = 1 - draw_prob - home_win_prob
#Probability that both team will score
both_team_score_goal_list = []
for i in home_goals_probs:
    both_team_score_goal_list.append(i*away_goals_probs[0])
for j in away_goals_probs[1:]:
    both_team_score_goal_list.append(j*home_goals_probs[0])
both_team_score_prob = 1 - sum(both_team_score_goal_list)

# %%
print(both_team_score_prob, away_win_prob, home_win_prob,draw_prob,home_goal_pred,away_goal_pred)
# Out:
# 0.5118005535238919 0.11980565619722183 0.7065309400005166 0.17366340380226153 2 0

# %%
def get_match_info(test):
    try:
        team1 =  test['home_team']
        stadium = test['stadium']
        team2 = test['away_team']
        league_name = test['competition']
        unix_time = test['match_time']
        list_days = {'Mon':'Thứ Hai','Tue':'Thứ Ba','Wed':'Thứ Tư','Thu':'Thứ Năm','Fri':'Thứ Sáu','Sat':'Thứ Bảy','Sun':'Chủ Nhật'}
        day_of_week_vi = list_days[time.strftime("%a", time.localtime(unix_time-0*3600))]
        date_dmy =time.strftime("%d/%m/%Y", time.localtime(unix_time-0*3600))
        time_hm= time.strftime("%H:%M", time.localtime(unix_time-0*3600))
        homeaway_h2h = json.loads(test['h2h'])[0]['matches']
        ##home and away head2head stats
        #team1 as home 
        team1_h2h_home_scores = []
        for i in homeaway_h2h:
            if i['home_name']== team1:
                team1_h2h_home_scores.append(i['home_scores'][0])
        #team2 as away
        team2_h2h_away_scores = []
        for i in homeaway_h2h:
            if i['away_name']== team2:
                team2_h2h_away_scores.append(i['away_scores'][0]) 
            
        #Avg team 1 h2h home scores 5 recent games
        team1_avg_h2h_home_scores = np.mean(team1_h2h_home_scores[0:5])
        #Avg team 2 h2h away score 5 recent games
        team2_avg_h2h_away_scores = np.mean(team2_h2h_away_scores[0:5])
        #H2H recents 5 games
        homeaway_h2h = json.loads(test['h2h'])[0]['matches'][0:5]
        team1_h2h_stats = {'win':0,'draw':0,'loss':0}
        for i in homeaway_h2h:
            if i['home_scores'] > i['away_scores']:
                if i['home_name'] == team1:
                    team1_h2h_stats['win']+=1
                else:
                    team1_h2h_stats['loss']+=1
            elif i['home_scores'] == i['away_scores']:
                team1_h2h_stats['draw']+=1
            else:
                if i['home_name'] == team1:
                    team1_h2h_stats['loss']+=1
                else:
                    team1_h2h_stats['win']+=1
        #Team1 stats 5 recent games:
        home_stats = {'win':0,'draw':0,'loss':0}
        homeaway_home  =  json.loads(test['home'])[0]['matches'][0:5]
        for i in homeaway_home:
            if i['home_scores'] > i['away_scores']:
                if i['home_name'] == team1:
                    home_stats['win']+=1
                else:
                    home_stats['loss']+=1
            elif i['home_scores'] == i['away_scores']:
                home_stats['draw']+=1
            else:
                if i['home_name'] == team1:
                    home_stats['loss']+=1
                else:
                    home_stats['win']+=1
        #Team2 stats 5 recent games
        away_stats = {'win':0,'draw':0,'loss':0}
        homeaway_away =  json.loads(test['away'])[0]['matches'][0:5]
        for i in homeaway_away:
            if i['home_scores'] > i['away_scores']:
                if i['home_name'] == team2:
                    away_stats['win']+=1
                else:
                    away_stats['loss']+=1
            elif i['home_scores'] == i['away_scores']:
                away_stats['draw']+=1
            else:
                if i['home_name'] == team2:
                    away_stats['loss']+=1
                else:
                    away_stats['win']+=1
        #Team1 GA and GF scores
        #team1_home_ga_scores=[]
        team1_home_gf_scores=[]
        homeaway_home = json.loads(test['home'])[0]['matches']
        for i in homeaway_home:
            if i['home_name']== team1:
                team1_home_ga_scores.append(i['home_scores'][0])
                team1_home_gf_scores.append(i['away_scores'][0])
        team1_avg_home_gf_scores = np.mean(team1_home_gf_scores)
        team2_away_gf_scores=[]
        homeaway_away = json.loads(test['away'])[0]['matches']
        for i in homeaway_away:
            if i['away_name']== team2:
                team2_away_gf_scores.append(i['away_scores'][0])
                #team2_away_gf_scores.append(i['home_scores'][0])
        team2_avg_away_gf_scores = np.mean(team2_away_gf_scores)
    
        #team1_home_eg_adjst_ratio = (team1_avg_h2h_home_scores + team1_avg_home_gf_scores)/2
        #team2_away_eg_adjst_ratio = (team2_avg_h2h_away_scores + team2_avg_away_gf_scores)/2
        #Home and Away EG
        home_eg = (team1_avg_h2h_home_scores + team1_avg_home_gf_scores)/2
        away_eg = (team2_avg_h2h_away_scores + team2_avg_away_gf_scores)/2
        def poisson_goal(g,eg):
            return (math.e**(-eg)*eg**g)/(math.factorial(g))
        #Home team goals probabilty, assume goals only in range 0-7
        home_goals_probs = []
        for i in range(0,8):
            prob = poisson_goal(i,home_eg)
            home_goals_probs.append(prob)
        #Away team goals probability, assume that goals are only in range 0-7
        away_goals_probs = []
        for i in range(0,8):
            prob = poisson_goal(i,away_eg)
            away_goals_probs.append(prob)
        #Home and Away goals prediction:
        home_goal_pred = home_goals_probs.index(max(home_goals_probs))
        away_goal_pred = away_goals_probs.index(max(away_goals_probs))
        #Probability that Home team win:
        home_win_prob_list = []
        for i in range(0,len(home_goals_probs)):
            for j in range(0,len(away_goals_probs)):
                if j < i:
                    home_win_prob_list.append(home_goals_probs[i]*away_goals_probs[j])
        home_win_prob = sum(home_win_prob_list)
        #Probability that both team draw:
        draw_prob = sum(np.array(home_goals_probs)*np.array(away_goals_probs))
        #Probability that Away team win:
        away_win_prob = 1 - draw_prob - home_win_prob
        #Probability that both team will score
        both_team_score_goal_list = []
        for i in home_goals_probs:
            both_team_score_goal_list.append(i*away_goals_probs[0])
        for j in away_goals_probs[1:]:
            both_team_score_goal_list.append(j*home_goals_probs[0])
        both_team_score_prob = 1 - sum(both_team_score_goal_list)
        return team1,team2,league_name,day_of_week_vi,date_dmy,time_hm,stadium,team1_h2h_stats,home_stats,away_stats,home_goal_pred,away_goal_pred,home_win_prob,away_win_prob,draw_prob,both_team_score_prob
    except TypeError as e:
        return None
def write_content4turbo(team1,team2,league_name,day_of_week_vi,date_dmy,time_hm,stadium,team1_h2h_stats,home_stats,away_stats,home_goal_pred,away_goal_pred,home_win_prob,away_win_prob,draw_prob,both_team_score_prob):
        completion = client.chat.completions.create(
        model = "gpt-3.5-turbo",
        temperature = 1.0,
        max_tokens = 2000,
        messages = [
            {"role": "system", "content": "bạn là là một chuyên gia sáng tạo nội dung cho website"}, 
            {"role": "system", "content": "bạn có am hiểu về phân tích và nhận định các trận bóng đá"}, 
            {"role": "system", "content": "Bạn chỉ đưa ra nhận định dựa trên những số liệu thống kê được cung cấp mà không sử dụng thêm thông tin bên ngoài."}, 
            {"role": "system", "content": f"""Các số liệu thống kê trước trận đấu giữa {team1} và {team2} được trình bày như sau:Trong 5 lần gặp nhau gần nhất giữa {team1} và {team2}, {team1} thắng {team1_h2h_stats['win']} thua {team1_h2h_stats['loss']} và hòa {team1_h2h_stats['draw']} 
    Trong 5 trận gần nhất của giải đấu {league_name}, {team1} thắng {home_stats['win']}, thua {home_stats['loss']} hòa {home_stats['draw']}.
    Trong 5 trận gần nhất của giải đấu {league_name} team B thắng {away_stats['win']}, hòa {away_stats['draw']}, thua {away_stats['loss']}. 
    AI của chúng tôi dự đoán tỉ số của trận đấu này sẽ là {home_goal_pred}-{away_goal_pred}. Xác suất thắng của {team1} là {np.round(100*home_win_prob,2)}%, xác suất thắng của team B là {np.round(100*away_win_prob,2)}%, xác suất để 2 đội hòa nhau là {np.round(100*draw_prob,2)}% và xác suất để cả hai team cùng ghi bàn là {np.round(100*both_team_score_prob,2)}%. """}, 
            {"role": "user", "content": f"Dựa vào những thông tin trên, hãy viết một bài nhận định và dự đoán về trận đấu giữa chủ nhà {team1} và {team2} diễn ra vào {time_hm} ngày {day_of_week_vi}, {date_dmy} tại sân vận động {stadium}"},         
            {"role": "user", "content": "Bài viết phải có sắc thái chuyên nghiệp, khách quan và có tính thuyết phục"},
            {"role": "user", "content": "Bài viết phải sử dụng toàn bộ các thông tin đã được cung cấp"}]
            
        )
        return completion.choices[0].message.content

# %%
test = []
for key, value in enumerate(match_dict):
    item = get_match_info(match_dict[key])
    test.append(item)
test
# Out:
# [['Backa Topola',
#   'Habitpharm Javor',
#   'Serbian Super liga',
#   'Thứ Hai',
#   '18/12/2023',
#   '23:00',
#   'Stadion Senta',
#   {'win': 4, 'draw': 0, 'loss': 1},
#   {'win': 0, 'draw': 0, 'loss': 5},
#   {'win': 2, 'draw': 0, 'loss': 3},
#   2,
#   0,
#   0.7065309400005166,
#   0.11980565619722183,
#   0.17366340380226153,
#   0.5118005535238919]]

# %%
match_dict
# Out:
# {0: {'match_id': 'dj2ryoh1go2kq1z',
#   'competition': 'Tanzanian Premier League',
#   'stadium': None,
#   'city': None,
#   'home_team': 'JKT Tanzania',
#   'away_team': 'Coastal Union',
#   'match_time': 1702913400,
#   'h2h': None,
#   'home': None,
#   'away': None},
#  1: {'match_id': 'dj2ryoh1go2kq1z',
#   'competition': 'Tanzanian Premier League',
#   'stadium': None,
#   'city': None,
#   'home_team': 'JKT Tanzania',
#   'away_team': 'Coastal Union',
#   'match_time': 1702913400,
#   'h2h': None,
#   'home': None,
#   'away': None},
#  2: {'match_id': '4jwq2ghzlg0om0v',
#   'competition': 'Greek Super League',
#   'stadium': 'Panetolikos Stadium',
#   'city': 'Agrinio',
#   'home_team': 'Panaitolikos Agrinio',
#   'away_team': 'AEK Athens',
#   'match_time': 1702911600,
#   'h2h': '[{"competition_id":"e4wyrn4hoeq86pv","competition_name":"Greek Super League","competition_logo":"\\/football\\/competition\\/37a57bd4441b06ee2f59c99f4a96fbf5.png","matches":[{"match_id":"318q66h6l8vzqo9","match_time":1696782600,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[3,2,0,0,9,0,0],"away_scores":[0,0,0,2,5,0,0]},{"match_id":"k82rekh0xzj8rep","match_time":1673791200,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[4,2,0,0,8,0,0],"away_scores":[1,1,0,4,2,0,0]},{"match_id":"y0or5jhzoxndqwz","match_time":1663434000,"status_id":8,"home_team_id":"v2y8m4zh97lql07","home_name":"Panaitolikos Agrinio","home_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","away_team_id":"v2y8m4zh9y8ql07","away_name":"AEK Athens","away_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","home_scores":[0,0,0,2,0,0,0],"away_scores":[2,0,0,3,7,0,0]},{"match_id":"ednm9wh0n29dryo","match_time":1642346100,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[1,1,0,1,6,0,0],"away_scores":[2,0,0,1,1,0,0]},{"match_id":"4wyrn4hl3lj0q86","match_time":1633266000,"status_id":8,"home_team_id":"v2y8m4zh97lql07","home_name":"Panaitolikos Agrinio","home_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","away_team_id":"v2y8m4zh9y8ql07","away_name":"AEK Athens","away_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","home_scores":[1,0,0,2,4,0,0],"away_scores":[3,2,0,2,6,0,0]},{"match_id":"8yomo4h4g8y1q0j","match_time":1609946100,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[1,1,0,2,5,0,0],"away_scores":[0,0,0,3,2,0,0]},{"match_id":"l5ergph8yv43r8k","match_time":1600536600,"status_id":8,"home_team_id":"v2y8m4zh97lql07","home_name":"Panaitolikos Agrinio","home_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","away_team_id":"v2y8m4zh9y8ql07","away_name":"AEK Athens","away_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","home_scores":[0,0,0,1,1,0,0],"away_scores":[2,0,0,6,7,0,0]},{"match_id":"jw2r09h7xl86rz8","match_time":1578229200,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[3,1,0,4,8,0,0],"away_scores":[1,1,0,4,1,0,0]},{"match_id":"23xmvkhwd31jqg8","match_time":1569085200,"status_id":8,"home_team_id":"v2y8m4zh97lql07","home_name":"Panaitolikos Agrinio","home_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","away_team_id":"v2y8m4zh9y8ql07","away_name":"AEK Athens","away_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","home_scores":[0,0,0,0,2,0,0],"away_scores":[1,0,0,2,3,0,0]},{"match_id":"vjxm8gh2725lr6o","match_time":1554041700,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"v2y8m4zh97l ...
#   'home': '[{"competition_id":"vl7oqdeh8lr510j","competition_name":"Greek Cup","competition_logo":"\\/football\\/competition\\/1bf163c9c97591667d1da9330b17140d.png","matches":[{"match_id":"pxwrxlh596pdryk","match_time":1701797400,"status_id":8,"home_team_id":"v2y8m4zh97lql07","home_name":"Panaitolikos Agrinio","home_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","away_team_id":"kdj2ryoh06jq1zp","away_name":"Kallithea","away_logo":"\\/football\\/team\\/8b16ebc056e613024c057be590b542eb.gif","home_scores":[3,0,0,3,3,0,0],"away_scores":[2,1,0,3,6,0,0]},{"match_id":"vjxm8ghlgye3r6o","match_time":1697033700,"status_id":8,"home_team_id":"x7lm7phk6xkm2wd","home_name":"Diagoras","home_logo":"\\/football\\/team\\/b40614ecb83fff172bedf6b1ee347be8.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[1,1,0,6,1,1,3],"away_scores":[1,1,0,4,2,1,4]}]},{"competition_id":"e4wyrn4hoeq86pv","competition_name":"Greek Super League","competition_logo":"\\/football\\/competition\\/37a57bd4441b06ee2f59c99f4a96fbf5.png","matches":[{"match_id":"3glrw7h3d4ogqdy","match_time":1701531000,"status_id":8,"home_team_id":"v2y8m4zh97lql07","home_name":"AE Kifisias","home_logo":"\\/football\\/team\\/a05129cd59a3398990f083f5daa1f19c.png","away_team_id":"n54qllhxx1gqvy9","away_name":"AE Kifisias","away_logo":"\\/football\\/team\\/a05129cd59a3398990f083f5daa1f19c.png","home_scores":[3,1,0,2,5,0,0],"away_scores":[0,0,0,5,6,0,0]},{"match_id":"l7oqdeh87j13r51","match_time":1700926200,"status_id":8,"home_team_id":"56ypq3nhywpmd7o","home_name":"Olympiakos Piraeus","home_logo":"\\/football\\/team\\/fcf62204578f5bbf95d254759781bef7.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[3,2,0,3,3,0,0],"away_scores":[1,1,0,1,2,0,0]},{"match_id":"y39mp1h07d9jmoj","match_time":1699803000,"status_id":8,"home_team_id":"v2y8m4zhy8vql07","home_name":"PAOK Saloniki","home_logo":"\\/football\\/team\\/4d15f8d9d3cdbbe522ac63ff1dff3b3b.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[2,2,0,2,4,0,0],"away_scores":[1,1,0,3,1,0,0]},{"match_id":"n54qllhpv4j0qvy","match_time":1699192800,"status_id":8,"home_team_id":"v2y8m4zh97lql07","home_name":"Panaitolikos Agrinio","home_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","away_team_id":"gy0or5jhywnqwzv","away_name":"Asteras Tripolis","away_logo":"\\/football\\/team\\/dbd8fbe82c9a39a85054bd7a2ac99b24.png","home_scores":[0,0,0,6,8,0,0],"away_scores":[1,1,1,4,3,0,0]},{"match_id":"dj2ryohe87neq1z","match_time":1698512400,"status_id":8,"home_team_id":"gx7lm7phy23m2wd","home_name":"Atromitos Athens","home_logo":"\\/football\\/team\\/3f319bdc494c875729cf4b19fde89c14.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[3,0,0,2,1,0,0],"away_scores":[2,1,1,1,2,0,0]},{"match_id":"318q66h6l8jjqo9","match_time":1697898600,"status_id":8,"home_team_id":"v2y8m4zh97lql07","home_name":"Panaitolikos Agrinio","home_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","away_team_id":"3glrw7hjjg8qdyj","away_name":"Volos NFC","away_logo":"\\/football\\/team\\/0019264819f39359ff8233af6a1c3609.png","home_scores":[2,1,0,2,3,0,0],"away_scores":[0,0,0,3,6,0,0]},{"match_id":"318q66h6l8vzqo9","match_time":1696782600,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"v2y8m4zh97lql07","away_name":"Panaitolikos Agrinio","away_logo":"\\/football\\/team\\/57fc3a67bb806c6577345f5f7c1d3e39.png","home_scores":[3,2,0,0,9,0,0],"away_scores":[0,0,0,2,5,0,0]},{"match_id":"23xmvkhp7yknqg8","match_time":1696 ...
#   'away': '[{"competition_id":"56ypq3nh0xmd7oj","competition_name":"UEFA Europa League","competition_logo":"\\/football\\/competition\\/1792ba5a12171fedc6d543bdf173f37c.png","matches":[{"match_id":"vjxm8ghl46ldr6o","match_time":1702584000,"status_id":8,"home_team_id":"jednm9whl7kryox","home_name":"AFC Ajax","home_logo":"\\/football\\/team\\/f7768c66a58a4318f14f48cefb1cb420.png","away_team_id":"v2y8m4zh9y8ql07","away_name":"AEK Athens","away_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","home_scores":[3,2,0,4,5,0,0],"away_scores":[1,1,0,3,5,0,0]},{"match_id":"965mkyhy7xker1g","match_time":1701366300,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"9k82rekhd6orepz","away_name":"Brighton Hove Albion","away_logo":"\\/football\\/team\\/9b43a690d5a09f1e319f036821e8e1d3.png","home_scores":[0,0,1,2,4,0,0],"away_scores":[1,0,0,1,4,0,0]},{"match_id":"ednm9wh7k4wzryo","match_time":1699560000,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"kjw2r09hyl1rz84","away_name":"Marseille","away_logo":"\\/football\\/team\\/a450173b3d636ba2c86d3d7c5bdc4026.png","home_scores":[0,0,0,2,15,0,0],"away_scores":[2,1,0,1,5,0,0]},{"match_id":"x7lm7phzkez6m2w","match_time":1698338700,"status_id":8,"home_team_id":"kjw2r09hyl1rz84","home_name":"Marseille","home_logo":"\\/football\\/team\\/a450173b3d636ba2c86d3d7c5bdc4026.png","away_team_id":"v2y8m4zh9y8ql07","away_name":"AEK Athens","away_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","home_scores":[3,1,0,2,3,0,0],"away_scores":[1,0,1,3,0,0,0]},{"match_id":"4jwq2ghe4jnkm0v","match_time":1696524300,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"jednm9whl7kryox","away_name":"AFC Ajax","away_logo":"\\/football\\/team\\/f7768c66a58a4318f14f48cefb1cb420.png","home_scores":[1,0,0,4,7,0,0],"away_scores":[1,1,0,2,4,0,0]},{"match_id":"1l4rjnh46096m7v","match_time":1695322800,"status_id":8,"home_team_id":"9k82rekhd6orepz","home_name":"Brighton Hove Albion","home_logo":"\\/football\\/team\\/9b43a690d5a09f1e319f036821e8e1d3.png","away_team_id":"v2y8m4zh9y8ql07","away_name":"AEK Athens","away_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","home_scores":[2,1,0,4,11,0,0],"away_scores":[3,2,0,7,2,0,0]}]},{"competition_id":"e4wyrn4hoeq86pv","competition_name":"Greek Super League","competition_logo":"\\/football\\/competition\\/37a57bd4441b06ee2f59c99f4a96fbf5.png","matches":[{"match_id":"2y8m4zhwlv16ql0","match_time":1701716400,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"kjw2r09hvylrz84","away_name":"Aris Thessaloniki","away_logo":"\\/football\\/team\\/d361fe8ab5fa2c7fb4f29d1fd4ee1094.png","home_scores":[1,0,0,1,9,0,0],"away_scores":[0,0,0,1,2,0,0]},{"match_id":"dn1m1ghp6911moe","match_time":1701010800,"status_id":8,"home_team_id":"kdj2ryoh0pwq1zp","home_name":"Pas Giannina","home_logo":"\\/football\\/team\\/a042dfe2a31dde9eb6145308be88b970.png","away_team_id":"v2y8m4zh9y8ql07","away_name":"AEK Athens","away_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","home_scores":[0,0,0,3,3,0,0],"away_scores":[1,1,0,1,6,0,0]},{"match_id":"zp5rzgh683xnq82","match_time":1699810200,"status_id":8,"home_team_id":"v2y8m4zh9y8ql07","home_name":"AEK Athens","home_logo":"\\/football\\/team\\/cfbb124fe648b7b871f2df5c1be15d76.png","away_team_id":"1l4rjnh6x74m7vx","away_name":"Lamia","away_logo":"\\/football\\/team\\/30cbc58c8960348899639e022349fe59.png","home_scores":[3,2,0,3,4,0,0],"away_scores":[0,0,0,3,4,0,0]},{"match_id":"vjxm8gh5ykpor6o","match_time":1699120800,"status_id":8,"home_team_id":"n54qllhxx1gqvy9","home_name":"AE Ki ...
#  3: {'match_id': 'y39mp1hzvk6nmoj',
#   'competition': 'Ghana Premier League',
#   'stadium': 'Accra Sports Stadium',
#   'city': 'Accra',
#   'home_team': 'Accra Lions',
#   'away_team': 'Nsoatreman FC',
#   'match_time': 1702911600,
#   'h2h': '[{"competition_id":"z318q66howkqo9j","competition_name":"Ghana Premier League","competition_logo":"\\/football\\/competition\\/9ac2b9eeb9ba9f6851558593f91c9bf9.png","matches":[{"match_id":"vjxm8gh5lpp9r6o","match_time":1679238000,"status_id":8,"home_team_id":"2y8m4zhz03xql07","home_name":"Nsoatreman FC","home_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","away_team_id":"dn1m1gh3l0xmoep","away_name":"Accra Lions","away_logo":"\\/football\\/team\\/0976841c0edddd3df56d0f33e0e1ec2e.png","home_scores":[3,2,0,0,0,0,0],"away_scores":[0,0,0,0,0,0,0]},{"match_id":"pxwrxlhx5j64ryk","match_time":1667660400,"status_id":8,"home_team_id":"dn1m1gh3l0xmoep","home_name":"Accra Lions","home_logo":"\\/football\\/team\\/0976841c0edddd3df56d0f33e0e1ec2e.png","away_team_id":"2y8m4zhz03xql07","away_name":"Nsoatreman FC","away_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","home_scores":[2,2,0,3,2,0,0],"away_scores":[0,0,0,2,6,0,0]}]}]',
#   'home': '[{"competition_id":"z318q66howkqo9j","competition_name":"Ghana Premier League","competition_logo":"\\/football\\/competition\\/9ac2b9eeb9ba9f6851558593f91c9bf9.png","matches":[{"match_id":"x7lm7phzg5j8m2w","match_time":1702220400,"status_id":8,"home_team_id":"4jwq2ghk0d9m0ve","home_name":"Bechem United","home_logo":"\\/football\\/team\\/fba82a6a587200cc1bf7e1b8086343d7.png","away_team_id":"dn1m1gh3l0xmoep","away_name":"Accra Lions","away_logo":"\\/football\\/team\\/0976841c0edddd3df56d0f33e0e1ec2e.png","home_scores":[4,2,0,2,8,0,0],"away_scores":[0,0,0,1,4,0,0]},{"match_id":"6ypq3nh364v6md7","match_time":1701615600,"status_id":8,"home_team_id":"dn1m1gh3l0xmoep","home_name":"Accra Lions","home_logo":"\\/football\\/team\\/0976841c0edddd3df56d0f33e0e1ec2e.png","away_team_id":"k82rekh38y2repz","away_name":"Nations FC","away_logo":"\\/football\\/team\\/31e3871ea479066b14b9ccde63797427.png","home_scores":[0,0,0,1,4,0,0],"away_scores":[1,0,0,1,4,0,0]},{"match_id":"318q66hwz7w1qo9","match_time":1701010800,"status_id":8,"home_team_id":"2y8m4zhj4z4ql07","home_name":"Aduana Stars","home_logo":"\\/football\\/team\\/1fa664e4116c55386e7c9fb39fec8edc.png","away_team_id":"dn1m1gh3l0xmoep","away_name":"Accra Lions","away_logo":"\\/football\\/team\\/0976841c0edddd3df56d0f33e0e1ec2e.png","home_scores":[0,0,0,1,6,0,0],"away_scores":[1,0,0,1,2,0,0]},{"match_id":"n54qllh75k7dqvy","match_time":1700578800,"status_id":8,"home_team_id":"dn1m1gh3l0xmoep","home_name":"Accra Lions","home_logo":"\\/football\\/team\\/0976841c0edddd3df56d0f33e0e1ec2e.png","away_team_id":"x7lm7phkkolm2wd","away_name":"Accra Hearts of Oak","away_logo":"\\/football\\/team\\/405f6ac55cfe7e97ae3e397f4f2b95ce.png","home_scores":[1,1,0,2,8,0,0],"away_scores":[2,1,0,1,5,0,0]},{"match_id":"dj2ryoh1vdezq1z","match_time":1699628400,"status_id":8,"home_team_id":"dn1m1gh3l0xmoep","home_name":"Accra Lions","home_logo":"\\/football\\/team\\/0976841c0edddd3df56d0f33e0e1ec2e.png","away_team_id":"3glrw7hjd22qdyj","away_name":"Karela United FC","away_logo":"\\/football\\/team\\/1a95b3f6d527a4e0c6bc9092dfb241cd.jfif","home_scores":[2,1,0,0,2,0,0],"away_scores":[1,0,0,0,3,0,0]},{"match_id":"k82rekhwz802rep","match_time":1699196400,"status_id":8,"home_team_id":"318q66h49wjqo9j","home_name":"Bibiani Gold Stars","home_logo":"\\/football\\/team\\/1e381d2f4bca502d3a5249cd70dbbec5.png","away_team_id":"dn1m1gh3l0xmoep","away_name":"Accra Lions","away_logo":"\\/football\\/team\\/0976841c0edddd3df56d0f33e0e1ec2e.png","home_scores":[1,0,0,1,0,0,0],"away_scores":[1,0,0,1,0,0,0]},{"match_id":"vjxm8ghlv25jr6o","match_time":1698937200,"status_id":8,"home_team_id":"dn1m1gh3l0xmoep","home_name":"Heart of Lions","home_logo":"\\/football\\/team\\/c18744b19c813409f63f946bcac0d3d8.png","away_team_id":"4wyrn4he08dq86p","away_name":"Heart of Lions","away_logo":"\\/football\\/team\\/c18744b19c813409f63f946bcac0d3d8.png","home_scores":[2,2,0,2,5,0,0],"away_scores":[1,0,0,0,4,0,0]},{"match_id":"dj2ryoh1vdxzq1z","match_time":1698418800,"status_id":8,"home_team_id":"965mkyh46gxr1ge","home_name":"Bofoakwa Tano","home_logo":"\\/football\\/team\\/3f5c1ce70ff72a5bb00821c7f5fea454.png","away_team_id":"dn1m1gh3l0xmoep","away_name":"Bofoakwa Tano","away_logo":"\\/football\\/team\\/3f5c1ce70ff72a5bb00821c7f5fea454.png","home_scores":[1,1,0,2,5,0,0],"away_scores":[1,0,0,2,1,0,0]},{"match_id":"1l4rjnh4y3l5m7v","match_time":1697814000,"status_id":8,"home_team_id":"dn1m1gh3l0xmoep","home_name":"Accra Lions","home_logo":"\\/football\\/team\\/0976841c0edddd3df56d0f33e0e1ec2e.png","away_team_id":"jw2r09hxld1rz84","away_name":"Real Tamale United","away_logo":"\\/football\\/team\\/ee53d44cee880e0ff42749b6dda0290d.png","home_scores":[1,0,0,3,5,0,0],"away_scores":[3,2,0,1,4,0,0]},{"match_id":"vjxm8ghlv2wjr6o","match_time":1697468400,"status_id":8,"home_team_id":"3glrw7hwk14qdyj","home_name":"Great Olympics","home_logo":"\\/football\\/team\\/85ccd6446c5315c981b7c18fcba5b91b.png","away_team_id":"dn1m1gh3l0xmoep","away_name":"Accra  ...
#   'away': '[{"competition_id":"z318q66howkqo9j","competition_name":"Ghana Premier League","competition_logo":"\\/football\\/competition\\/9ac2b9eeb9ba9f6851558593f91c9bf9.png","matches":[{"match_id":"ednm9wh78dwpryo","match_time":1702220400,"status_id":8,"home_team_id":"2y8m4zhz03xql07","home_name":"Nsoatreman FC","home_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","away_team_id":"3glrw7hjd22qdyj","away_name":"Karela United FC","away_logo":"\\/football\\/team\\/1a95b3f6d527a4e0c6bc9092dfb241cd.jfif","home_scores":[0,0,0,0,0,0,0],"away_scores":[1,0,0,0,0,0,0]},{"match_id":"vjxm8ghlv2ejr6o","match_time":1701615600,"status_id":8,"home_team_id":"318q66h49wjqo9j","home_name":"Bibiani Gold Stars","home_logo":"\\/football\\/team\\/1e381d2f4bca502d3a5249cd70dbbec5.png","away_team_id":"2y8m4zhz03xql07","away_name":"Nsoatreman FC","away_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","home_scores":[1,0,0,0,0,0,0],"away_scores":[2,1,0,0,0,0,0]},{"match_id":"2y8m4zh60462ql0","match_time":1701010800,"status_id":8,"home_team_id":"2y8m4zhz03xql07","home_name":"Nsoatreman FC","home_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","away_team_id":"4wyrn4he08dq86p","away_name":"Heart of Lions","away_logo":"\\/football\\/team\\/c18744b19c813409f63f946bcac0d3d8.png","home_scores":[0,0,0,0,0,0,0],"away_scores":[0,0,1,0,0,0,0]},{"match_id":"4jwq2gheo0e9m0v","match_time":1700406000,"status_id":8,"home_team_id":"965mkyh46gxr1ge","home_name":"Bofoakwa Tano","home_logo":"\\/football\\/team\\/3f5c1ce70ff72a5bb00821c7f5fea454.png","away_team_id":"2y8m4zhz03xql07","away_name":"Nsoatreman FC","away_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","home_scores":[0,0,0,0,0,0,0],"away_scores":[0,0,0,0,0,0,0]},{"match_id":"x7lm7phzg5zwm2w","match_time":1699801200,"status_id":8,"home_team_id":"2y8m4zhz03xql07","home_name":"Nsoatreman FC","home_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","away_team_id":"jw2r09hxld1rz84","away_name":"Real Tamale United","away_logo":"\\/football\\/team\\/ee53d44cee880e0ff42749b6dda0290d.png","home_scores":[2,1,0,0,0,0,0],"away_scores":[0,0,1,0,0,0,0]},{"match_id":"n54qllh75kzdqvy","match_time":1699542000,"status_id":8,"home_team_id":"6ypq3nh5eo3md7o","home_name":"Medeama SC","home_logo":"\\/football\\/team\\/d70a5c966fba9397ad39c59232120f3f.png","away_team_id":"2y8m4zhz03xql07","away_name":"Nsoatreman FC","away_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","home_scores":[1,0,0,3,6,0,0],"away_scores":[0,0,0,3,2,0,0]},{"match_id":"dn1m1gh2vopgmoe","match_time":1699286400,"status_id":8,"home_team_id":"3glrw7hwk14qdyj","home_name":"Great Olympics","home_logo":"\\/football\\/team\\/85ccd6446c5315c981b7c18fcba5b91b.png","away_team_id":"2y8m4zhz03xql07","away_name":"Nsoatreman FC","away_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","home_scores":[2,0,0,2,6,0,0],"away_scores":[1,1,0,2,3,0,0]},{"match_id":"4jwq2gheo0z9m0v","match_time":1698937200,"status_id":8,"home_team_id":"2y8m4zhz03xql07","home_name":"Nsoatreman FC","home_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","away_team_id":"23xmvkh33v5qg8n","away_name":"Asante Kotoko FC","away_logo":"\\/football\\/team\\/1aebdbe417fee71ed90b83b2e9ab3405.png","home_scores":[1,1,0,0,0,0,0],"away_scores":[0,0,1,3,0,0,0]},{"match_id":"jw2r09h24p0yrz8","match_time":1698591600,"status_id":8,"home_team_id":"n54qllhekj0qvy9","home_name":"Berekum Chelsea","home_logo":"\\/football\\/team\\/25be2c016b619de9cafdc1249961e6ae.png","away_team_id":"2y8m4zhz03xql07","away_name":"Nsoatreman FC","away_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","home_scores":[0,0,0,0,0,0,0],"away_scores":[1,1,0,0,0,0,0]},{"match_id":"4wyrn4hxz7l1q86","match_time":1697986800,"status_id":8,"home_team_id":"2y8m4zhz03xql07","home_name":"Nsoatreman FC","home_logo":"\\/football\\/team\\/694e752dc839dab8fc723f763b1c8c29.png","away_team_id":"8yomo4hve6jq0j6","away_ ...
#  4: {'match_id': 'k82rekh0l7xdrep',
#   'competition': 'Serbian Super liga',
#   'stadium': 'Stadion Senta',
#   'city': 'Senta',
#   'home_team': 'Backa Topola',
#   'away_team': 'Habitpharm Javor',
#   'match_time': 1702911600,
#   'h2h': '[{"competition_id":"yl5ergphk2r8k0o","competition_name":"Serbian Super liga","competition_logo":"\\/football\\/competition\\/53c39d0e222d0707324dcf86dd20ca23.png","matches":[{"match_id":"k82rekh0l73wrep","match_time":1692552600,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,0,3,6,0,0],"away_scores":[3,3,0,2,5,0,0]},{"match_id":"y0or5jhz04dyqwz","match_time":1667044800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,0,2,6,0,0],"away_scores":[1,0,0,2,5,0,0]},{"match_id":"318q66h670xzqo9","match_time":1657994400,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[0,0,0,0,5,0,0],"away_scores":[0,0,0,4,0,0,0]},{"match_id":"4wyrn4hllxvpq86","match_time":1620563400,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[2,2,1,2,3,0,0],"away_scores":[1,1,0,3,3,0,0]},{"match_id":"4jwq2gh917kom0v","match_time":1608472800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[1,0,1,3,6,0,0],"away_scores":[2,0,0,2,4,0,0]},{"match_id":"8yomo4h9k869q0j","match_time":1590939000,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[6,2,0,1,7,0,0],"away_scores":[1,0,0,1,10,0,0]},{"match_id":"6ypq3nhg587wmd7","match_time":1571500800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[3,1,0,5,5,0,0],"away_scores":[2,2,0,3,6,0,0]}]},{"competition_id":"kjw2r09h59rz84o","competition_name":"Serbian Prva Liga","competition_logo":"\\/football\\/competition\\/14c0fe418966f38de7fb573148830ed6.png","matches":[{"match_id":"pxwrxlh2ddgyryk","match_time":1554559200,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[4,2,0,0,-1,0,0],"away_scores":[2,1,0,0,-1,0,0]},{"match_id":"jw2r09hpky1drz8","match_time":1543406400,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[3,3,0,2,4,0,0],"away_scores":[1,1,0,3,3,0,0]},{"match_id":"n54qllhkng2vqvy","match_time":1535216400,"status_id": ...
#   'home': '[{"competition_id":"56ypq3nh0xmd7oj","competition_name":"UEFA Europa League","competition_logo":"\\/football\\/competition\\/1792ba5a12171fedc6d543bdf173f37c.png","matches":[{"match_id":"dn1m1gh24z2kmoe","match_time":1702584000,"status_id":8,"home_team_id":"56ypq3nhywpmd7o","home_name":"Olympiakos Piraeus","home_logo":"\\/football\\/team\\/fcf62204578f5bbf95d254759781bef7.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[5,3,0,0,3,0,0],"away_scores":[2,0,1,5,1,0,0]},{"match_id":"2y8m4zh6396vql0","match_time":1701366300,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"gy0or5jhdwxqwzv","away_name":"West Ham United","away_logo":"\\/football\\/team\\/d71ebda5c7fbca9093a1c2978c46f619.png","home_scores":[0,0,0,2,1,0,0],"away_scores":[1,0,0,2,8,0,0]},{"match_id":"dj2ryoh1k01lq1z","match_time":1699560000,"status_id":8,"home_team_id":"l965mkyh924r1ge","home_name":"SC Freiburg","home_logo":"\\/football\\/team\\/6508946c9a5fe22a8784b905b25e8c79.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[5,1,0,1,10,0,0],"away_scores":[0,0,0,1,3,0,0]},{"match_id":"6ypq3nh30o3pmd7","match_time":1698338700,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"l965mkyh924r1ge","away_name":"SC Freiburg","away_logo":"\\/football\\/team\\/6508946c9a5fe22a8784b905b25e8c79.png","home_scores":[1,1,0,3,1,0,0],"away_scores":[3,0,0,1,5,0,0]},{"match_id":"8yomo4h37o38q0j","match_time":1696524300,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"56ypq3nhywpmd7o","away_name":"Olympiakos Piraeus","away_logo":"\\/football\\/team\\/fcf62204578f5bbf95d254759781bef7.png","home_scores":[2,0,0,1,1,0,0],"away_scores":[2,1,1,1,3,0,0]},{"match_id":"318q66hwopw7qo9","match_time":1695322800,"status_id":8,"home_team_id":"gy0or5jhdwxqwzv","home_name":"West Ham United","home_logo":"\\/football\\/team\\/d71ebda5c7fbca9093a1c2978c46f619.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[3,0,0,1,12,0,0],"away_scores":[1,0,0,1,4,0,0]}]},{"competition_id":"yl5ergphk2r8k0o","competition_name":"Serbian Super liga","competition_logo":"\\/football\\/competition\\/53c39d0e222d0707324dcf86dd20ca23.png","matches":[{"match_id":"3glrw7h3dvpzqdy","match_time":1702123200,"status_id":8,"home_team_id":"k82rekhvekkrepz","home_name":"Radnicki 1923 Kragujevac","home_logo":"\\/football\\/team\\/33e7ad6e34950bb9743e157561f60341.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,1,2,0,0,0],"away_scores":[0,0,0,2,3,0,0]},{"match_id":"2y8m4zhwlkp3ql0","match_time":1701619200,"status_id":8,"home_team_id":"1l4rjnh1wklm7vx","home_name":"Backa Topola","home_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","away_team_id":"d23xmvkh5k4qg8n","away_name":"Radnicki Nis","away_logo":"\\/football\\/team\\/794c52e40471e247cc8e50dc33841c1d.png","home_scores":[1,0,0,3,7,0,0],"away_scores":[0,0,1,2,1,0,0]},{"match_id":"1l4rjnhjvw54m7v","match_time":1700933400,"status_id":8,"home_team_id":"gpxwrxlhogxryk0","home_name":"Partizan Belgrade","home_logo":"\\/football\\/team\\/f2cc8904afb100d60dfe9266b3ded7cf.png","away_team_id":"1l4rjnh1wklm7vx","away_name":"Backa Topola","away_logo":"\\/football\\/team\\/7b645392a40dff6e97fd9d9b43af09dd.png","home_scores":[0,0,0,3,3,0,0],"away_scores":[4,3,0,2,5,0,0]},{"match_id":"y0or5jhz726jqwz","match_time":1699813800,"status_id":8, ...
#   'away': '[{"competition_id":"yl5ergphk2r8k0o","competition_name":"Serbian Super liga","competition_logo":"\\/football\\/competition\\/53c39d0e222d0707324dcf86dd20ca23.png","matches":[{"match_id":"pxwrxlhxdk3jryk","match_time":1702216800,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"56ypq3nh2p9md7o","away_name":"FK \\u010cukari\\u010dki","away_logo":"\\/football\\/team\\/4ad5f5bcfdad804518271ed830bbecc1.png","home_scores":[1,0,0,5,1,0,0],"away_scores":[2,1,0,1,6,0,0]},{"match_id":"jw2r09h68o9erz8","match_time":1701444600,"status_id":8,"home_team_id":"kn54qllhg5yqvy9","home_name":"Novi Pazar","home_logo":"\\/football\\/team\\/993a9b2e250b69aabc350618ada0b139.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[2,0,0,2,2,0,0],"away_scores":[0,0,1,5,3,0,0]},{"match_id":"zp5rzgh68l46q82","match_time":1701097200,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"4zp5rzghlweq82w","away_name":"FK Vozdovac Beograd","away_logo":"\\/football\\/team\\/cd95dbc4c415200eafa8f40625fe59a7.png","home_scores":[4,1,0,2,3,0,0],"away_scores":[0,0,0,0,6,0,0]},{"match_id":"y0or5jhz726eqwz","match_time":1699803000,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"8yomo4h7zxnq0j6","away_name":"FK Spartak Zlatibor Voda","away_logo":"\\/football\\/team\\/f9febad819c8bf2e552267e14127c5b7.png","home_scores":[2,1,0,2,6,0,0],"away_scores":[0,0,0,1,5,0,0]},{"match_id":"8yomo4hgnd9dq0j","match_time":1699293600,"status_id":8,"home_team_id":"1l4rjnh67zgm7vx","home_name":"Mladost Lucani","home_logo":"\\/football\\/team\\/e64d3418718f4415783fcfaca7db3448.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[1,1,0,4,6,0,0],"away_scores":[0,0,0,2,5,0,0]},{"match_id":"k82rekh0l7nwrep","match_time":1698422400,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"Habitpharm Javor","home_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","away_team_id":"jw2r09hl16yrz84","away_name":"FK Napredak Krusevac","away_logo":"\\/football\\/team\\/7d35c67da2b80a3092e25e784ce21762.png","home_scores":[0,0,1,0,4,0,0],"away_scores":[2,2,0,0,4,0,0]},{"match_id":"x7lm7ph341nom2w","match_time":1697905800,"status_id":8,"home_team_id":"9k82rekh44krepz","home_name":"Crvena Zvezda","home_logo":"\\/football\\/team\\/61a1f9406cde098a265280a3683da9b7.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[3,1,0,0,9,0,0],"away_scores":[2,0,0,3,6,0,0]},{"match_id":"2y8m4zhwlk4oql0","match_time":1696694400,"status_id":8,"home_team_id":"p3glrw7hd10qdyj","home_name":"FK Zeleznicar Pancevo","home_logo":"\\/football\\/team\\/5a4205b9ee3d49c60df7bf22bc2e2203.png","away_team_id":"23xmvkhdvz8qg8n","away_name":"FK Zeleznicar Pancevo","away_logo":"\\/football\\/team\\/5a4205b9ee3d49c60df7bf22bc2e2203.png","home_scores":[2,1,0,1,5,0,0],"away_scores":[1,0,0,3,7,0,0]},{"match_id":"dn1m1ghp6wo9moe","match_time":1696168800,"status_id":8,"home_team_id":"y39mp1h3ek1mojx","home_name":"Radnik Surdulica","home_logo":"\\/football\\/team\\/cf83cf4ba24bbed391992ef0423a41db.png","away_team_id":"p3glrw7hd10qdyj","away_name":"Habitpharm Javor","away_logo":"\\/football\\/team\\/8c6b1bebd4c1223ea8eb9a3e8554ff3e.png","home_scores":[0,0,0,1,1,0,0],"away_scores":[1,0,0,1,5,0,0]},{"match_id":"3glrw7h3dvlkqdy","match_time":1695489000,"status_id":8,"home_team_id":"4zp5rzghkp1q82w","home_name":"Vojvodina Novi Sad","home_logo":"\\/football\\/team\\/40ce8b99981bc319 ...

# %%
get_match_info(test)

# %%
from openai import OpenAI
openai.api_key = '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'
openai.api_key
# Out:
# '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'

# %%
team1,team2,league_name,day_of_week_vi,date_dmy,time_hm,stadium,team1_h2h_stats,home_stats,away_stats,home_goal_pred,away_goal_pred,home_win_prob,away_win_prob,draw_prob,both_team_score_prob = get_match_info(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 team1,team2,league_name,day_of_week_vi,date_dmy,time_hm,stadium,team1_h2h_stats,home_stats,away_stats,home_goal_pred,away_goal_pred,home_win_prob,away_win_prob,draw_prob,both_team_score_prob = get_match_info(test)
#
# NameError: name 'get_match_info' is not defined

# %%
content = write_content4turbo(team1,team2,league_name,day_of_week_vi,date_dmy,time_hm,stadium,team1_h2h_stats,home_stats,away_stats,home_goal_pred,away_goal_pred,home_win_prob,away_win_prob,draw_prob,both_team_score_prob)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[235], line 1
# ----> 1 content = write_content4turbo(team1,team2,league_name,day_of_week_vi,date_dmy,time_hm,stadium,team1_h2h_stats,home_stats,away_stats,home_goal_pred,away_goal_pred,home_win_prob,away_win_prob,draw_prob,both_team_score_prob)
#
# Cell In[228], line 136, in write_content4turbo(team1, team2, league_name, day_of_week_vi, date_dmy, time_hm, stadium, team1_h2h_stats, home_stats, away_stats, home_goal_pred, away_goal_pred, home_win_prob, away_win_prob, draw_prob, both_team_score_prob)
#     135 def write_content4turbo(team1,team2,league_name,day_of_week_vi,date_dmy,time_hm,stadium,team1_h2h_stats,home_stats,away_stats,home_goal_pred,away_goal_pred,home_win_prob,away_win_prob,draw_prob,both_team_score_prob):
# --> 136         completion = client.chat.completions.create(
#     137         model = "gpt-3.5-turbo",
#     138         temperature = 1.0,
#     139         max_tokens = 2000,
#     140         messages = [
#     141             {"role": "system", "content": "bạn là là một chuyên gia sáng tạo nội dung cho website"},
#     142             {"role": "system", "content": "bạn có am hiểu về phân tích và nhận định các trận bóng đá"},
#     143             {"role": "system", "content": "Bạn chỉ đưa ra nhận định dựa trên những số liệu thống kê được cung cấp mà không sử dụng thêm thông tin bên ngoài."},
#     144             {"role": "system", "content": f"""Các số liệu thống kê trước trận đấu giữa {team1} và {team2} được trình bày như sau:Trong 5 lần gặp nhau gần nhất giữa {team1} và {team2}, {team1} thắng {team1_h2h_stats['win']} thua {team1_h2h_stats['loss']} và hòa {team1_h2h_stats['draw']}
#     145     Trong 5 trận gần nhất của giải đấu {league_name}, {team1} thắng {home_stats['win']}, thua {home_stats['loss']} hòa {home_stats['draw']}.
#     146     Trong 5 trận gần nhất của giải đấu {league_name} team B thắng {away_stats['win']}, hòa {away_stats['draw']}, thua {away_stats['loss']}.
#     147     AI của chúng tôi dự đoán tỉ số của trận đấu này sẽ là {home_goal_pred}-{away_goal_pred}. Xác suất thắng của {team1} là {np.round(100*home_win_prob,2)}%, xác suất thắng của team B là {np.round(100*away_win_prob,2)}%, xác suất để 2 đội hòa nhau là {np.round(100*draw_prob,2)}% và xác suất để cả hai team cùng ghi bàn là {np.round(100*both_team_score_prob,2)}%. """},
#     148             {"role": "user", "content": f"Dựa vào những thông tin trên, hãy viết một bài nhận định và dự đoán về trận đấu giữa chủ nhà {team1} và {team2} diễn ra vào {time_hm} ngày {day_of_week_vi}, {date_dmy} tại sân vận động {stadium}"},
#     149             {"role": "user", "content": "Bài viết phải có sắc thái chuyên nghiệp, khách quan và có tính thuyết phục"},
#     150             {"role": "user", "content": "Bài viết phải sử dụng toàn bộ các thông tin đã được cung cấp"}]
#     151
#     152         )
#     153         return completion.choices[0].message.content
#
# NameError: name 'client' is not defined

# %%
from openai import OpenAI

# %%
from openai import OpenAI

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key='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',
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        }
    ],
    model="gpt-3.5-turbo",
)

print(chat_completion.choices[0].message)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 from openai import OpenAI
# ----> 3 client = OpenAI(
#       4     # defaults to os.environ.get("OPENAI_API_KEY")
#       5     api_key='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',
#       6 )
#       8 chat_completion = client.chat.completions.create(
#       9     messages=[
#      10         {
#    (...)
#      15     model="gpt-3.5-turbo",
#      16 )
#      18 print(chat_completion.choices[0].message)
#
# File ~\anaconda3\Lib\site-packages\openai\_client.py:106, in OpenAI.__init__(self, api_key, organization, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     103 if base_url is None:
#     104     base_url = f"https://api.openai.com/v1"
# --> 106 super().__init__(
#     107     version=__version__,
#     108     base_url=base_url,
#     109     max_retries=max_retries,
#     110     timeout=timeout,
#     111     http_client=http_client,
#     112     custom_headers=default_headers,
#     113     custom_query=default_query,
#     114     _strict_response_validation=_strict_response_validation,
#     115 )
#     117 self._default_stream_cls = Stream
#     119 self.completions = resources.Completions(self)
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:758, in SyncAPIClient.__init__(self, version, base_url, max_retries, timeout, transport, proxies, limits, http_client, custom_headers, custom_query, _strict_response_validation)
#     743         timeout = DEFAULT_TIMEOUT
#     745 super().__init__(
#     746     version=version,
#     747     limits=limits,
#    (...)
#     756     _strict_response_validation=_strict_response_validation,
#     757 )
# --> 758 self._client = http_client or SyncHttpxClientWrapper(
#     759     base_url=base_url,
#     760     # cast to a valid type because mypy doesn't understand our type narrowing
#     761     timeout=cast(Timeout, timeout),
#     762     proxies=proxies,
#     763     transport=transport,
#     764     limits=limits,
#     765 )
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:672, in Client.__init__(self, auth, params, headers, cookies, verify, cert, http1, http2, proxies, mounts, timeout, follow_redirects, limits, max_redirects, event_hooks, base_url, transport, app, trust_env, default_encoding)
#     669 allow_env_proxies = trust_env and app is None and transport is None
#     670 proxy_map = self._get_proxy_map(proxies, allow_env_proxies)
# --> 672 self._transport = self._init_transport(
#     673     verify=verify,
#     674     cert=cert,
#     675     http1=http1,
#     676     http2=http2,
#     677     limits=limits,
#     678     transport=transport,
#     679     app=app,
#     680     trust_env=trust_env,
#     681 )
#     682 self._mounts: typing.Dict[URLPattern, typing.Optional[BaseTransport]] = {
#     683     URLPattern(key): None
#     684     if proxy is None
#    (...)
#     694     for key, proxy in proxy_map.items()
#     695 }
#     696 if mounts is not None:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:720, in Client._init_transport(self, verify, cert, http1, http2, limits, transport, app, trust_env)
#     717 if app is not None:
#     718     return WSGITransport(app=app)
# --> 720 return HTTPTransport(
#     721     verify=verify,
#     722     cert=cert,
#     723     http1=http1,
#     724     http2=http2,
#     725     limits=limits,
#     726     trust_env=trust_env,
#     727 )
#
# File ~\anaconda3\Lib\site-packages\httpx\_transports\default.py:136, in HTTPTransport.__init__(self, verify, cert, http1, http2, limits, trust_env, proxy, uds, local_address, retries, socket_options)
#     133 ssl_context = create_ssl_context(verify=verify, cert=cert, trust_env=trust_env)
#     135 if proxy is None:
# --> 136     self._pool = httpcore.ConnectionPool(
#     137         ssl_context=ssl_context,
#     138         max_connections=limits.max_connections,
#     139         max_keepalive_connections=limits.max_keepalive_connections,
#     140         keepalive_expiry=limits.keepalive_expiry,
#     141         http1=http1,
#     142         http2=http2,
#     143         uds=uds,
#     144         local_address=local_address,
#     145         retries=retries,
#     146         socket_options=socket_options,
#     147     )
#     148 elif proxy.url.scheme in ("http", "https"):
#     149     self._pool = httpcore.HTTPProxy(
#     150         proxy_url=httpcore.URL(
#     151             scheme=proxy.url.raw_scheme,
#    (...)
#     165         socket_options=socket_options,
#     166     )
#
# TypeError: ConnectionPool.__init__() got an unexpected keyword argument 'socket_options'

# %%
# !python --version
# Out:
# Python 3.11.5
